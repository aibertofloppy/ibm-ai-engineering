# %% [markdown]
# # Capítulo 2 – Variables and Statements
#
# Este notebook contiene ejercicios prácticos del **Capítulo 2** del libro *Think Python 3e*.
#
# Objetivos:
# - Aprender qué es una variable y cómo se usa en Python.
# - Comprender las sentencias y expresiones.
# - Practicar operaciones con distintos tipos de datos.

# %% [markdown]
# ## Ejercicio 1: Crear y mostrar variables
#
# Crea una variable llamada `nombre` y otra `edad`. Muestra un mensaje con ambos valores.

# %%
# Tu solución aquí
nombre = "Ayberto"
edad = 25
print("Mi nombre es", nombre, "y tengo", edad, "años")

# %% [markdown]
# ## Ejercicio 2: Operaciones con variables numéricas
#
# Declara dos variables numéricas y realiza operaciones básicas (suma, resta, multiplicación y división).

# %%
a = 10
b = 3

print("Suma:", a + b)
print("Resta:", a - b)
print("Multiplicación:", a * b)
print("División:", a / b)

# %% [markdown]
# ## Ejercicio 3: Conversión de tipos
#
# Convierte un número entero a cadena y viceversa, y verifica los tipos con `type()`.

# %%
numero = 42
texto = str(numero)
print(texto, type(texto))

texto_numero = "123"
entero = int(texto_numero)
print(entero, type(entero))

# %% [markdown]
# ## Ejercicio 4: Cálculo con variables
#
# Calcula el área de un círculo usando la fórmula `área = pi * radio^2` y muestra el resultado.

# %%
pi = 3.1416
radio = 5
area = pi * radio ** 2
print("El área del círculo es:", area)
